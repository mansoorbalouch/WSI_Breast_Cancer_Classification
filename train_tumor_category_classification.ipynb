# %% [markdown]
# DenseNet model with weights available for benign/malignant classification

# %%
##### Predicting the class labels #########

import os
import torch
from torchvision import transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
from PIL import Image
import numpy as np
import pandas as pd
import sys
from breast_cancer_detection.model import model

# %%
main_dir = "/media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project"
pretrained_model_dir = f"{main_dir}/WSI_Breast_Cancer_Classification/breast_cancer_detection"
model_path_dir = f'{pretrained_model_dir}/saved/'
model_config = f"{model_path_dir}/config.json"
model_path = f"{model_path_dir}/model_best.pth"

# Ensure the directory containing custom modules is in the path
sys.path.append(f'{main_dir}/WSI_Breast_Cancer_Classification/breast_cancer_detection')

class ImageFolderWithPaths(ImageFolder):

    def __getitem__(self, index):
  
        img, label = super(ImageFolderWithPaths, self).__getitem__(index)
        
        path = self.imgs[index][0]
        
        return (img, label ,path)



def load_pretrained_model(model_path):
    # Load the entire checkpoint
    checkpoint = torch.load(model_path, map_location=torch.device('cpu'))
    
    # Assuming you're using a ResNet and it's defined correctly
    myModel = model.densenet121()  # Ensure this uses the correct block and layer definitions as used during training
    
    # Load state dictionary
    myModel.load_state_dict(checkpoint['state_dict'])

    myModel.eval()
    return myModel


# Assuming the model expects images to be 224x224 pixels
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # Resize the image to fit the model input
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Normalization
])


def predict_and_save(model, image_loader):
    model.eval()  # Set the model to evaluation mode
    predictions = []
    
    with torch.no_grad():
        for image, label, path in image_loader:  # Assuming image_loader yields both images and their paths
            # image = image.to(device)
            output = model(image)
            _, predicted = torch.max(output, 1)
            head, tail = os.path.split(path[0])
            predictions.append((os.path.splitext(tail)[0], predicted.item()))  # Collect filename and predicted label

    return predictions


def save_predictions_to_csv(predictions, output_file='Labels/Predicted_labels_benign_malignant.csv'):
    # Convert predictions list to DataFrame
    df = pd.DataFrame(predictions, columns=['Filename', 'Label'])
    # Save to CSV
    df.to_csv(output_file, index=False)


# Load the model
myModel = load_pretrained_model(model_path)

# Directory containing images
image_directory =  f"{main_dir}/Tiles_Data" 
image_files = [os.path.join(image_directory, img) for img in os.listdir(image_directory) if img.endswith('.png')]

# Setup DataLoader
dataset = ImageFolderWithPaths(root=image_directory, transform=transform)
image_loader = DataLoader(dataset, batch_size=1, shuffle=False)  # Batch size set to 1 to handle images one by one


# Get predictions
predictions = predict_and_save(myModel, image_loader)

# Save predictions to CSV
save_predictions_to_csv(predictions)

# %%
myModel = torch.load(model_path, map_location=torch.device('cpu'))
myModel

# %%
class ImageFolderWithPaths(ImageFolder):

    def __getitem__(self, index):
  
        img, label = super(ImageFolderWithPaths, self).__getitem__(index)
        
        path = self.imgs[index][0]
        
        return (img, label ,path)

dataset = ImageFolderWithPaths(image_directory,transform=transform) # add transformation directly

dataloader = DataLoader(dataset)


for image, labels, path in dataloader:
    print(os.path.split(path))

# %%
import torch
import torch.nn as nn
from torchvision import models, datasets, transforms
from breast_cancer_detection.model import model 
import torch.optim as optim


def load_pretrained_model(model_path, num_classes=2):
    checkpoint = torch.load(model_path, map_location=torch.device('cpu'))
    
    # Load your custom model
    myModel = model.densenet121()  # Replace this with the actual function if different
    
    # Assuming the classifier might need to be adjusted
    num_ftrs = myModel.classifier.in_features
    myModel.classifier = torch.nn.Linear(num_ftrs, num_classes)

    # Load state dictionary
    myModel.load_state_dict(checkpoint['state_dict'])

    myModel.eval()  # Set the model to evaluation mode
    return myModel


def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs=25, device='cpu'):
    best_acc = 0.0  # Initialize the best accuracy
    best_model_path = 'best_model.pth'  # Define path to save the best model

    for epoch in range(num_epochs):
        model.train()  # Set model to training mode
        running_loss = 0.0
        running_corrects = 0

        # Training phase
        for inputs, labels in train_loader:
            inputs = inputs.to(device)
            labels = labels.to(device)

            optimizer.zero_grad()

            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item() * inputs.size(0)
            _, preds = torch.max(outputs, 1)
            running_corrects += torch.sum(preds == labels.data)

        epoch_loss = running_loss / len(train_loader.dataset)
        epoch_acc = running_corrects.double() / len(train_loader.dataset)
        print(f'Epoch {epoch+1}/{num_epochs} - Train Loss: {epoch_loss:.4f}, Acc: {epoch_acc:.4f}')

        # Validation phase
        model.eval()
        val_loss = 0.0
        val_corrects = 0

        for inputs, labels in val_loader:
            inputs = inputs.to(device)
            labels = labels.to(device)

            with torch.no_grad():
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                _, preds = torch.max(outputs, 1)

            val_loss += loss.item() * inputs.size(0)
            val_corrects += torch.sum(preds == labels.data)

        val_loss = val_loss / len(val_loader.dataset)
        val_acc = val_corrects.double() / len(val_loader.dataset)
        print(f'Validation Loss: {val_loss:.4f}, Acc: {val_acc:.4f}')

        # Check if this is the best model and save
        if val_acc > best_acc:
            best_acc = val_acc
            torch.save(model.state_dict(), best_model_path)
            print(f'New best model saved with accuracy: {best_acc:.4f}')

    print('Training complete')
    return model


# Define transformations for the input data
transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# Setup data directories
data_dir = '/path/to/your/data_directory'  # Adjust as per your directory structure
train_dir = os.path.join(data_dir, 'train')
val_dir = os.path.join(data_dir, 'val')

# Create datasets using ImageFolder
train_dataset = datasets.ImageFolder(root=train_dir, transform=transform)
val_dataset = datasets.ImageFolder(root=val_dir, transform=transform)

# Create DataLoaders
batch_size = 16  # Adjust based on your system capability
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

model = load_pretrained_model(num_classes=2)
model = model.to('cuda' if torch.cuda.is_available() else 'cpu')

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.fc.parameters(), lr=0.001)  # Only optimize the final layer

# Setup the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# Call the training function
model = train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs=10, device=device)

# %%
##### Label prediction example #########

import os
import torch
from torchvision import transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
from PIL import Image
import numpy as np
import sys

main_dir = "/media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project"
pretrained_model_dir = f"{main_dir}/WSI_Breast_Cancer_Classification/breast_cancer_detection"
model_path_dir = f'{pretrained_model_dir}/saved/'
model_config = f"{model_path_dir}/config.json"
model_path = f"{model_path_dir}/model_best.pth"

# Ensure the directory containing custom modules is in the path
sys.path.append(f'{main_dir}/WSI_Breast_Cancer_Classification/breast_cancer_detection')

from breast_cancer_detection.parse_config import ConfigParser  


import json
with open(model_config) as config_file:
    config_dict = json.load(config_file)

config = ConfigParser(config=config_dict)  

from breast_cancer_detection.model import model 


def load_pretrained_model(model_path):
    # Load the entire checkpoint
    checkpoint = torch.load(model_path, map_location=torch.device('cpu'))
    
    # Assuming you're using a ResNet and it's defined correctly
    myModel = model.densenet121()  # Ensure this uses the correct block and layer definitions as used during training
    
    # Load state dictionary
    myModel.load_state_dict(checkpoint['state_dict'])

    # myModel = model.ResNet(block=model.BasicBlock, num_blocks=[3, 4, 6, 3], num_classes=2)
    # myModel.load_state_dict(torch.load(model_path, map_location=torch.device('cpu')))
    myModel.eval()
    return myModel

# Define a function to preprocess images
def preprocess_image(image_path):
    # Assuming the model expects images to be 224x224 pixels
    transform = transforms.Compose([
        transforms.Resize((224, 224)),  # Resize the image to fit the model input
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Normalization
    ])
    image = Image.open(image_path)
    image = transform(image).unsqueeze(0)  # Add batch dimension
    return image

# Function to predict labels
def predict(model, image_path):
    image = preprocess_image(image_path)
    with torch.no_grad():
        outputs = model(image)
        _, predicted = torch.max(outputs, 1)
    return predicted.item()


tiles_dir =  f"{main_dir}/test_tiles" 
save_model_path = f"{main_dir}/WSI_Breast_Cancer_Classification/Model_Weights"


# Load the model
myModel = load_pretrained_model(model_path)

# Directory containing images
image_directory =  f"{main_dir}/test_tiles/n_14_test" 
image_files = [os.path.join(image_directory, img) for img in os.listdir(image_directory) if img.endswith('.png')]

# Predict labels for each image
predictions = {img: predict(myModel, img) for img in image_files}

# Print the predictions
for img_path, label in predictions.items():
    print(f'Image: {img_path}, Predicted Label: {"Benign" if label == 0 else "Malignant"}')
# Out:
# Warning: logging configuration file is not found in logger/logger_config.json.
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(14_41).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(102_29).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(102_31).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(103_28).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(103_29).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(103_30).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(103_31).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(104_27).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(104_28).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(104_29).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(104_30).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(104_31).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(105_26).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(105_27).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(105_28).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(7_35).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(7_36).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(7_37).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(7_38).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(7_39).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(7_40).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(7_45).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(80_48).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(81_48).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(8_34).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(8_35).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(8_36).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(8_37).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(8_38).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(8_45).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(8_46).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(9_33).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(9_34).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(9_35).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(9_36).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(9_37).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(9_44).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(9_45).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(9_46).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(9_47).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(9_48).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(11_35).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(11_45).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(11_46).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(11_47).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(11_48).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(120_21).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(120_22).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(120_23).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(120_37).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(120_38).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(120_39).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(120_40).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(120_41).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(120_42).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(12_45).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(12_46).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(12_47).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(13_27).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(13_28).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(13_29).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(13_30).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(13_31).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(13_32).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(13_33).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(13_40).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(13_41).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(13_42).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(13_43).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(105_29).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(107_26).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(108_40).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(10_36).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(110_37).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(111_36).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(112_35).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(114_10).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(115_30).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(118_23).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(11_34).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(120_43).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(121_8).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(123_21).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(124_36).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(126_33).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(128_31).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(12_44).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(13_44).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(13_45).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(13_46).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(14_24).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(14_25).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(14_26).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(14_27).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(14_28).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(14_29).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(14_30).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(14_31).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(14_37).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(14_38).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(14_39).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(14_40).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(14_42).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(14_43).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(14_44).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(14_45).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(15_18).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(15_24).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(15_25).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(15_26).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(15_27).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(15_28).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(15_29).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(15_30).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(15_35).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(15_36).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(15_38).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(15_39).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(15_40).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(15_41).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(15_42).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(16_24).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(16_26).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(16_27).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(16_34).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(16_35).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(16_37).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(16_38).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(16_39).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(16_40).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(17_17).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(17_18).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(17_19).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(17_24).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(17_32).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(17_33).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(17_34).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(17_35).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(17_37).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(17_38).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(18_15).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(18_16).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(18_31).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(18_32).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(18_34).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(18_35).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(18_36).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(18_37).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(19_14).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(19_15).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(19_16).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(19_30).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(19_31).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(19_32).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(19_33).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(19_34).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(19_35).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(20_14).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(20_16).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(20_17).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(20_30).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(20_31).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(20_32).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(20_33).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(21_12).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(21_15).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(21_16).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(21_29).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(21_30).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(21_31).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(21_32).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(21_48).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(21_50).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(21_51).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(22_14).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(22_15).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(22_28).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(22_29).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(22_30).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(22_31).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(22_45).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(22_47).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(22_48).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(22_49).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(22_50).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(22_51).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(23_14).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(23_27).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(23_28).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(23_29).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(23_44).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(23_45).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(23_46).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(23_47).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(23_48).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(23_49).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(23_50).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(23_51).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(23_52).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(24_27).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(24_29).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(24_43).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(24_44).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(24_45).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(24_46).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(24_47).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(24_48).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(24_49).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(24_50).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(24_51).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(25_26).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(25_27).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(25_28).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(25_43).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(25_45).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(25_46).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(25_47).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(25_48).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(25_49).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(25_50).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(26_23).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(26_24).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(26_25).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(26_26).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(26_27).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(26_40).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(26_41).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(26_42).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(26_44).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(26_45).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(26_46).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(26_47).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(27_24).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(27_25).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(27_26).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(27_39).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(27_40).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(27_41).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(27_42).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(27_43).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(27_44).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(27_45).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(28_38).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(28_39).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(28_40).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(28_41).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(28_42).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(28_43).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(29_35).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(29_36).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(29_37).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(29_38).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(29_39).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(29_40).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(29_41).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(29_42).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(30_20).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(30_22).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(30_33).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(30_34).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(30_35).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(30_36).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(30_37).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(30_38).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(30_39).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(30_40).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(31_33).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(31_34).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(31_35).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(31_36).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(31_38).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(31_39).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(32_21).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(32_31).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(32_33).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(32_34).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(32_36).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(32_37).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(4_37).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(4_38).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(4_39).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(5_36).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(5_37).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(5_38).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(5_39).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(5_40).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(6_35).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(6_36).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(6_37).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(6_38).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(6_39).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(6_40).png, Predicted Label: Benign
# ...
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(120_7).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(120_8).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(121_20).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(121_21).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(121_22).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(121_37).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(121_38).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(121_39).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(121_40).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(121_42).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(121_43).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(121_7).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(15_37).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(17_16).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(18_33).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(20_15).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(21_49).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(23_13).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(24_28).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(25_44).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(26_43).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(28_37).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(30_19).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(31_37).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(7_34).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(122_20).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(122_21).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(122_22).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(122_36).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(122_37).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(122_38).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(122_39).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(122_40).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(122_41).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(122_42).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(122_43).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(122_6).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(123_19).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(123_20).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(123_35).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(123_36).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(123_37).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(123_38).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(123_39).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(123_40).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(124_17).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(124_18).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(124_19).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(124_20).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(124_32).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(124_33).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(124_34).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(124_35).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(124_37).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(124_38).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(125_17).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(125_18).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(125_19).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(125_31).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(125_32).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(125_33).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(125_34).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(125_35).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(125_36).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(126_30).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(126_31).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(126_32).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(126_34).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(126_35).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(127_28).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(127_29).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(127_30).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(127_31).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(127_32).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(127_33).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(127_34).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(128_26).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(128_27).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(128_28).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(128_29).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(128_30).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(128_32).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(128_33).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(129_27).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(129_28).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(129_29).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(129_30).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(129_31).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(12_28).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(12_29).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(12_30).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(12_31).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(12_32).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(12_33).png, Predicted Label: Malignant
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(12_34).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(12_42).png, Predicted Label: Benign
# Image: /media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project/test_tiles/n_14_test/SUB_n_14_tile_(12_43).png, Predicted Label: Malignant

# %%
##### does not have model weights available #########

import torch
from torchvision import transforms
from PIL import Image
from TransMIL import * 
from TransMIL.models import TransMIL
from TransMIL import MyOptimizer, MyLoss
from TransMIL.MyOptimizer import *


# Assume you have a function to load the model and it's been trained or a pre-trained model is loaded
model = TransMIL()
model.load_state_dict(torch.load('trans_mil_model.pth'))
model.eval()

# Image preprocessing
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # Resize if necessary
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

def classify_patch(image_path):
    image = Image.open(image_path).convert('RGB')
    image = transform(image).unsqueeze(0)  # Add batch dimension
    with torch.no_grad():
        outputs = model(image)
        _, predicted = torch.max(outputs, 1)
    return predicted.item()


# create file directory structure and train-test split (one time run when the file structure is not created)
main_dir = "/media/ist/Drive2/MANSOOR/Neuroimaging-Project/Breast_Cancer_Classification_Project"

tiles_dir =  f"{main_dir}/test_tiles" 
save_model_path = f"{main_dir}/WSI_Breast_Cancer_Classification/Model_Weights"

# Example usage
image_path = f'{tiles_dir}/n_14_test/SUB_n_14_tile_(6_38).png'
prediction = classify_patch(image_path)
print("Predicted class:", "Benign" if prediction == 0 else "Malignant")
